# %% [markdown]
# ## Reading and Understanding the Data

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from statsmodels.stats.outliers_influence import variance_inflation_factor
import statsmodels.api as sm
from sklearn.metrics import r2_score

import warnings
warnings.filterwarnings('ignore')

# %%
# Read the data from csv file

df = pd.read_csv(r'C:\Users\ADMIN\OneDrive\Desktop\UpGrad Resource\Linear Regressionn\Assignment\day.csv')

# %%
# Check the head of the dataset
 
df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  01-01-2018       1   0     1        0        1           1
# 1        2  02-01-2018       1   0     1        0        2           1
# 2        3  03-01-2018       1   0     1        0        3           1
# 3        4  04-01-2018       1   0     1        0        4           1
# 4        5  05-01-2018       1   0     1        0        5           1
#
#    weathersit       temp     atemp      hum  windspeed  casual  registered  \
# 0           2  14.110847  18.18125  80.5833  10.749882     331         654
# 1           2  14.902598  17.68695  69.6087  16.652113     131         670
# 2           1   8.050924   9.47025  43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610  59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350  43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# checking the shape of dataframe

df.shape
# Out:
# (730, 16)

# %%
# describing the columns of dataframe

df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean   365.500000    2.498630    0.500000    6.526027    0.028767    2.995890
# std    210.877136    1.110184    0.500343    3.450215    0.167266    2.000339
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.250000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    365.500000    3.000000    0.500000    7.000000    0.000000    3.000000
# 75%    547.750000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    730.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  730.000000  730.000000  730.000000  730.000000  730.000000  730.000000
# mean     0.690411    1.394521   20.319259   23.726322   62.765175   12.763620
# std      0.462641    0.544807    7.506729    8.150308   14.237589    5.195841
# min      0.000000    1.000000    2.424346    3.953480    0.000000    1.500244
# 25%      0.000000    1.000000   13.811885   16.889713   52.000000    9.041650
# 50%      1.000000    1.000000   20.465826   24.368225   62.625000   12.125325
# 75%      1.000000    2.000000   26.880615   30.445775   72.989575   15.625589
# max      1.000000    3.000000   35.328347   42.044800   97.250000   34.000021
#
#             casual   registered          cnt
# count   730.000000   730.000000   730.000000
# mean    849.249315  3658.757534  4508.006849
# std     686.479875  1559.758728  1936.011647
# min       2.000000    20.000000    22.000000
# 25%     316.250000  2502.250000  3169.750000
# 50%     717.000000  3664.500000  4548.500000
# 75%    1096.500000  4783.250000  5966.000000
# max    3410.000000  6946.000000  8714.000000

# %%
# get the info about columns

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     730 non-null    int64
#  1   dteday      730 non-null    object
#  2   season      730 non-null    int64
#  3   yr          730 non-null    int64
#  4   mnth        730 non-null    int64
#  5   holiday     730 non-null    int64
#  6   weekday     730 non-null    int64
#  7   workingday  730 non-null    int64
#  8   weathersit  730 non-null    int64
#  9   temp        730 non-null    float64
#  10  atemp       730 non-null    float64
#  11  hum         730 non-null    float64
#  12  windspeed   730 non-null    float64
#  13  casual      730 non-null    int64
#  14  registered  730 non-null    int64
#  15  cnt         730 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.4+ KB

# %%
# checking for the null values in column data

df.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
# renaming few columns for better readibility

df.rename(columns={'yr':'year','mnth':'month','hum':'humidity'}, inplace=True)

# %%
# Check the head of the dataset

df.head()
# Out:
#    instant      dteday  season  year  month  holiday  weekday  workingday  \
# 0        1  01-01-2018       1     0      1        0        1           1
# 1        2  02-01-2018       1     0      1        0        2           1
# 2        3  03-01-2018       1     0      1        0        3           1
# 3        4  04-01-2018       1     0      1        0        4           1
# 4        5  05-01-2018       1     0      1        0        5           1
#
#    weathersit       temp     atemp  humidity  windspeed  casual  registered  \
# 0           2  14.110847  18.18125   80.5833  10.749882     331         654
# 1           2  14.902598  17.68695   69.6087  16.652113     131         670
# 2           1   8.050924   9.47025   43.7273  16.636703     120        1229
# 3           1   8.200000  10.60610   59.0435  10.739832     108        1454
# 4           1   9.305237  11.46350   43.6957  12.522300      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
# Copying the dataframe into new

df1 = df.copy()

# %%
df1.shape
# Out:
# (730, 16)

# %%
df1.drop_duplicates(inplace=True)

# %%
df1.shape
# Out:
# (730, 16)

# %%
# dropping the unwanted columns
# instant has only index for the row, dteday has date which can be compensated by year and month column,
# casual and registered seems to be the breakup by category for cnt column.

df.drop(['instant','dteday','casual','registered'],axis=1,inplace=True)

# %%
# Encoding/mapping the season column

df.season = df.season.map({1:'spring', 2:'summer', 3:'fall', 4:'winter'})

# %%
# Encoding/mapping the month column

df.month = df.month.map({1:'jan',2:'feb',3:'mar',4:'apr',5:'may',6:'june',7:'july',8:'aug',9:'sep',10:'oct',11:'nov',12:'dec'})

# %%
# Encoding/mapping the weekday column

df.weekday = df.weekday.map({0:'sun',1:'mon',2:'tue',3:'wed',4:'thu',5:'fri',6:'sat'})

# %%
# Encoding/mapping the weathersit column

df.weathersit = df.weathersit.map({1:'Clear',2:'Misty',3:'Light_snowrain',4:'Heavy_snowrain'})

# %%
df.head()
# Out:
#    season  year month  holiday weekday  workingday weathersit       temp  \
# 0  spring     0   jan        0     mon           1      Misty  14.110847
# 1  spring     0   jan        0     tue           1      Misty  14.902598
# 2  spring     0   jan        0     wed           1      Clear   8.050924
# 3  spring     0   jan        0     thu           1      Clear   8.200000
# 4  spring     0   jan        0     fri           1      Clear   9.305237
#
#       atemp  humidity  windspeed   cnt
# 0  18.18125   80.5833  10.749882   985
# 1  17.68695   69.6087  16.652113   801
# 2   9.47025   43.7273  16.636703  1349
# 3  10.60610   59.0435  10.739832  1562
# 4  11.46350   43.6957  12.522300  1600

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   season      730 non-null    object
#  1   year        730 non-null    int64
#  2   month       730 non-null    object
#  3   holiday     730 non-null    int64
#  4   weekday     730 non-null    object
#  5   workingday  730 non-null    int64
#  6   weathersit  730 non-null    object
#  7   temp        730 non-null    float64
#  8   atemp       730 non-null    float64
#  9   humidity    730 non-null    float64
#  10  windspeed   730 non-null    float64
#  11  cnt         730 non-null    int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 68.6+ KB

# %% [markdown]
# ## Visualising the Data

# %%
# Analysing/visualizing the categorical columns
# to see how predictor variable stands against the target variable

plt.figure(figsize=(20, 12))
plt.subplot(2,4,1)
sns.boxplot(x = 'season', y = 'cnt', data = df)
plt.subplot(2,4,2)
sns.boxplot(x = 'month', y = 'cnt', data = df)
plt.subplot(2,4,3)
sns.boxplot(x = 'weekday', y = 'cnt', data = df)
plt.subplot(2,4,4)
sns.boxplot(x = 'weathersit', y = 'cnt', data = df)
plt.subplot(2,4,5)
sns.boxplot(x = 'holiday', y = 'cnt', data = df)
plt.subplot(2,4,6)
sns.boxplot(x = 'workingday', y = 'cnt', data = df)
plt.subplot(2,4,7)
sns.boxplot(x = 'year', y = 'cnt', data = df)
plt.show()

# %%
# function to create barplot related to categorical columns

def plot_cat_columns(column):
    plt.figure(figsize = (12,6))
    plt.subplot(1,2,1)
    sns.barplot(column,'cnt',data=df)
    plt.subplot(1,2,2)
    sns.barplot(column,'cnt',data=df, hue='year',palette='Set1')
    plt.legend(labels=['2018', '2019'])
    plt.show()

# %%
# Analysing/visualizing the numerical columns

sns.pairplot(data=df,vars=['temp','atemp','humidity','windspeed','cnt'])
plt.show()

# %%
# Checking the correlation between the numerical variables

plt.figure(figsize = (6,6))
matrix = np.triu(df[['temp','atemp','humidity','windspeed','cnt']].corr())
sns.heatmap(df[['temp','atemp','humidity','windspeed','cnt']].corr(), annot = True, cmap="RdYlGn", mask=matrix)
plt.title("Correlation between Numerical Variables")
plt.show()

# %% [markdown]
# ## Data Preperation

# %%
# Dummy variable creation for month, weekday, weathersit and season variables.

months_df=pd.get_dummies(df.month,drop_first=True)
weekdays_df=pd.get_dummies(df.weekday,drop_first=True)
weathersit_df=pd.get_dummies(df.weathersit,drop_first=True)
seasons_df=pd.get_dummies(df.season,drop_first=True)

# %%
df.head()
# Out:
#    season  year month  holiday weekday  workingday weathersit       temp  \
# 0  spring     0   jan        0     mon           1      Misty  14.110847
# 1  spring     0   jan        0     tue           1      Misty  14.902598
# 2  spring     0   jan        0     wed           1      Clear   8.050924
# 3  spring     0   jan        0     thu           1      Clear   8.200000
# 4  spring     0   jan        0     fri           1      Clear   9.305237
#
#       atemp  humidity  windspeed   cnt
# 0  18.18125   80.5833  10.749882   985
# 1  17.68695   69.6087  16.652113   801
# 2   9.47025   43.7273  16.636703  1349
# 3  10.60610   59.0435  10.739832  1562
# 4  11.46350   43.6957  12.522300  1600

# %%
# Merging  the dataframe, with the dummy variable dataset. 

df_new = pd.concat([df,months_df,weekdays_df,weathersit_df,seasons_df],axis=1)

# %%
df_new.head()
# Out:
#    season  year month  holiday weekday  workingday weathersit       temp  \
# 0  spring     0   jan        0     mon           1      Misty  14.110847
# 1  spring     0   jan        0     tue           1      Misty  14.902598
# 2  spring     0   jan        0     wed           1      Clear   8.050924
# 3  spring     0   jan        0     thu           1      Clear   8.200000
# 4  spring     0   jan        0     fri           1      Clear   9.305237
#
#       atemp  humidity  ...    sat    sun    thu    tue    wed  Light_snowrain  \
# 0  18.18125   80.5833  ...  False  False  False  False  False           False
# 1  17.68695   69.6087  ...  False  False  False   True  False           False
# 2   9.47025   43.7273  ...  False  False  False  False   True           False
# 3  10.60610   59.0435  ...  False  False   True  False  False           False
# 4  11.46350   43.6957  ...  False  False  False  False  False           False
#
#    Misty  spring  summer  winter
# 0   True    True   False   False
# 1   True    True   False   False
# 2  False    True   False   False
# 3  False    True   False   False
# 4  False    True   False   False
#
# [5 rows x 34 columns]

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 34 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   season          730 non-null    object
#  1   year            730 non-null    int64
#  2   month           730 non-null    object
#  3   holiday         730 non-null    int64
#  4   weekday         730 non-null    object
#  5   workingday      730 non-null    int64
#  6   weathersit      730 non-null    object
#  7   temp            730 non-null    float64
#  8   atemp           730 non-null    float64
#  9   humidity        730 non-null    float64
#  10  windspeed       730 non-null    float64
#  11  cnt             730 non-null    int64
#  12  aug             730 non-null    bool
#  13  dec             730 non-null    bool
#  14  feb             730 non-null    bool
#  15  jan             730 non-null    bool
#  16  july            730 non-null    bool
#  17  june            730 non-null    bool
#  18  mar             730 non-null    bool
#  19  may             730 non-null    bool
#  20  nov             730 non-null    bool
#  21  oct             730 non-null    bool
#  22  sep             730 non-null    bool
#  23  mon             730 non-null    bool
#  24  sat             730 non-null    bool
#  25  sun             730 non-null    bool
#  26  thu             730 non-null    bool
#  27  tue             730 non-null    bool
#  28  wed             730 non-null    bool
#  29  Light_snowrain  730 non-null    bool
#  30  Misty           730 non-null    bool
#  31  spring          730 non-null    bool
#  32  summer          730 non-null    bool
#  33  winter          730 non-null    bool
# dtypes: bool(22), float64(4), int64(4), object(4)
# memory usage: 84.2+ KB

# %%
# dropping unnecessary columns as we have already created dummy variable out of it.

df_new.drop(['season','month','weekday','weathersit'], axis = 1, inplace = True)

# %%
# check the head of new dataframe

df_new.head()
# Out:
#    year  holiday  workingday       temp     atemp  humidity  windspeed   cnt  \
# 0     0        0           1  14.110847  18.18125   80.5833  10.749882   985
# 1     0        0           1  14.902598  17.68695   69.6087  16.652113   801
# 2     0        0           1   8.050924   9.47025   43.7273  16.636703  1349
# 3     0        0           1   8.200000  10.60610   59.0435  10.739832  1562
# 4     0        0           1   9.305237  11.46350   43.6957  12.522300  1600
#
#      aug    dec  ...    sat    sun    thu    tue    wed  Light_snowrain  \
# 0  False  False  ...  False  False  False  False  False           False
# 1  False  False  ...  False  False  False   True  False           False
# 2  False  False  ...  False  False  False  False   True           False
# 3  False  False  ...  False  False   True  False  False           False
# 4  False  False  ...  False  False  False  False  False           False
#
#    Misty  spring  summer  winter
# 0   True    True   False   False
# 1   True    True   False   False
# 2  False    True   False   False
# 3  False    True   False   False
# 4  False    True   False   False
#
# [5 rows x 30 columns]

# %%
# check the shape of new dataframe

df_new.shape
# Out:
# (730, 30)

# %%
# check the column info of new dataframe 

df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 30 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   year            730 non-null    int64
#  1   holiday         730 non-null    int64
#  2   workingday      730 non-null    int64
#  3   temp            730 non-null    float64
#  4   atemp           730 non-null    float64
#  5   humidity        730 non-null    float64
#  6   windspeed       730 non-null    float64
#  7   cnt             730 non-null    int64
#  8   aug             730 non-null    bool
#  9   dec             730 non-null    bool
#  10  feb             730 non-null    bool
#  11  jan             730 non-null    bool
#  12  july            730 non-null    bool
#  13  june            730 non-null    bool
#  14  mar             730 non-null    bool
#  15  may             730 non-null    bool
#  16  nov             730 non-null    bool
#  17  oct             730 non-null    bool
#  18  sep             730 non-null    bool
#  19  mon             730 non-null    bool
#  20  sat             730 non-null    bool
#  21  sun             730 non-null    bool
#  22  thu             730 non-null    bool
#  23  tue             730 non-null    bool
#  24  wed             730 non-null    bool
#  25  Light_snowrain  730 non-null    bool
#  26  Misty           730 non-null    bool
#  27  spring          730 non-null    bool
#  28  summer          730 non-null    bool
#  29  winter          730 non-null    bool
# dtypes: bool(22), float64(4), int64(4)
# memory usage: 61.4 KB

# %% [markdown]
# ## Splitting the Data into Training and Testing Sets

# %%
# splitting the dataframe into Train and Test

np.random.seed(0)
df_train, df_test = train_test_split(df_new, train_size = 0.7, random_state = 100)

# %%
# check the shape of training datatset

df_train.shape
# Out:
# (510, 30)

# %%
# check the shape of testing datatset

df_test.shape
# Out:
# (220, 30)

# %%
# Using MinMaxScaler to Rescaling the features

scaler = MinMaxScaler()

# %%
# verifying the head of dataset before scaling.

df_train.head()
# Out:
#      year  holiday  workingday       temp    atemp  humidity  windspeed   cnt  \
# 576     1        0           1  29.246653  33.1448   70.4167  11.083475  7216
# 426     1        0           0  16.980847  20.6746   62.1250  10.792293  4066
# 728     1        0           1  10.489153  11.5850   48.3333  23.500518  1796
# 482     1        0           0  15.443347  18.8752   48.9583   8.708325  4220
# 111     0        0           0  13.803347  16.0977   72.9583  14.707907  1683
#
#        aug    dec  ...    sat    sun    thu    tue    wed  Light_snowrain  \
# 576  False  False  ...  False  False  False  False   True           False
# 426  False  False  ...  False   True  False  False  False           False
# 728  False   True  ...  False  False  False  False  False           False
# 482  False  False  ...  False   True  False  False  False           False
# 111  False  False  ...  False   True  False  False  False           False
#
#      Misty  spring  summer  winter
# 576  False   False   False   False
# 426   True    True   False   False
# 728  False    True   False   False
# 482   True   False    True   False
# 111   True   False    True   False
#
# [5 rows x 30 columns]

# %%
# Apply scaler() to all the columns except the 'yes-no' and 'dummy' variables

num_vars = ['temp','atemp','humidity','windspeed','cnt']
df_train[num_vars] = scaler.fit_transform(df_train[num_vars])

# %%
# verifying the head after appying scaling.

df_train.head()
# Out:
#      year  holiday  workingday      temp     atemp  humidity  windspeed  \
# 576     1        0           1  0.815169  0.766351  0.725633   0.264686
# 426     1        0           0  0.442393  0.438975  0.640189   0.255342
# 728     1        0           1  0.245101  0.200348  0.498067   0.663106
# 482     1        0           0  0.395666  0.391735  0.504508   0.188475
# 111     0        0           0  0.345824  0.318819  0.751824   0.380981
#
#           cnt    aug    dec  ...    sat    sun    thu    tue    wed  \
# 576  0.827658  False  False  ...  False  False  False  False   True
# 426  0.465255  False  False  ...  False   True  False  False  False
# 728  0.204096  False   True  ...  False  False  False  False  False
# 482  0.482973  False  False  ...  False   True  False  False  False
# 111  0.191095  False  False  ...  False   True  False  False  False
#
#      Light_snowrain  Misty  spring  summer  winter
# 576           False  False   False   False   False
# 426           False   True    True   False   False
# 728           False  False    True   False   False
# 482           False   True   False    True   False
# 111           False   True   False    True   False
#
# [5 rows x 30 columns]

# %%
# describing the dataset

df_train.describe()
# Out:
#              year     holiday  workingday        temp       atemp    humidity  \
# count  510.000000  510.000000  510.000000  510.000000  510.000000  510.000000
# mean     0.507843    0.025490    0.711765    0.537440    0.513156    0.650480
# std      0.500429    0.157763    0.453386    0.225858    0.212410    0.145846
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000    0.000000    0.339853    0.332086    0.538643
# 50%      1.000000    0.000000    1.000000    0.542596    0.529718    0.653714
# 75%      1.000000    0.000000    1.000000    0.735215    0.688457    0.754830
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#         windspeed         cnt
# count  510.000000  510.000000
# mean     0.320883    0.513499
# std      0.169803    0.224421
# min      0.000000    0.000000
# 25%      0.199179    0.356420
# 50%      0.296763    0.518638
# 75%      0.414447    0.684710
# max      1.000000    1.000000

# %%
# check the correlation coefficients to see which variables are highly correlated

plt.figure(figsize = (25,25))
matrix = np.triu(df_train.corr())
sns.heatmap(df_train.corr(), annot = True, cmap="RdYlGn", mask=matrix)
plt.show()

# %%
# Visualizing one of the correlation to see the trends via Scatter plot.

plt.figure(figsize=[6,6])
plt.scatter(df_train.temp, df_train.cnt)
plt.show()

# %%
# Building the Linear Model

y_train = df_train.pop('cnt')
X_train = df_train

# %%
# Recursive feature elimination 

lm = LinearRegression()
lm.fit(X_train, y_train)

rfe = RFE(lm, step = 15)
rfe = rfe.fit(X_train, y_train)

# %%
#List of variables selected in top 15 list

list(zip(X_train.columns,rfe.support_,rfe.ranking_))
# Out:
# [('year', True, 1),
#  ('holiday', True, 1),
#  ('workingday', True, 1),
#  ('temp', True, 1),
#  ('atemp', True, 1),
#  ('humidity', True, 1),
#  ('windspeed', True, 1),
#  ('aug', False, 2),
#  ('dec', False, 2),
#  ('feb', False, 2),
#  ('jan', True, 1),
#  ('july', False, 2),
#  ('june', False, 2),
#  ('mar', False, 2),
#  ('may', False, 2),
#  ('nov', False, 2),
#  ('oct', False, 2),
#  ('sep', True, 1),
#  ('mon', False, 2),
#  ('sat', True, 1),
#  ('sun', True, 1),
#  ('thu', False, 2),
#  ('tue', False, 2),
#  ('wed', False, 2),
#  ('Light_snowrain', True, 1),
#  ('Misty', True, 1),
#  ('spring', False, 2),
#  ('summer', False, 2),
#  ('winter', True, 1)]

# %%
# selecting the selected variable via RFE in col list

col = X_train.columns[rfe.support_]
print(col)
# Out:
# Index(['year', 'holiday', 'workingday', 'temp', 'atemp', 'humidity',
#        'windspeed', 'jan', 'sep', 'sat', 'sun', 'Light_snowrain', 'Misty',
#        'winter'],
#       dtype='object')

# %%
# checking which columns has been rejected

X_train.columns[~rfe.support_]
# Out:
# Index(['aug', 'dec', 'feb', 'july', 'june', 'mar', 'may', 'nov', 'oct', 'mon',
#        'thu', 'tue', 'wed', 'spring', 'summer'],
#       dtype='object')

# %%
# Generic function to calculate VIF of variables

def calculateVIF(df):
    vif = pd.DataFrame()
    vif['Features'] = df.columns
    vif['VIF'] = [variance_inflation_factor(df.values.astype(float), i) for i in range(df.shape[1])]
    vif['VIF'] = round(vif['VIF'], 2)
    vif = vif.sort_values(by = "VIF", ascending = False)
    return vif

# %%
# dataframe with RFE selected variables

X_train_rfe = X_train[col]

# %%
# calculate VIF

calculateVIF(X_train_rfe)
# Out:
#           Features     VIF
# 4            atemp  356.17
# 3             temp  345.80
# 5         humidity   35.54
# 2       workingday   30.61
# 10             sun    6.39
# 9              sat    6.08
# 6        windspeed    5.38
# 12           Misty    2.36
# 0             year    2.07
# 1          holiday    1.76
# 13          winter    1.74
# 7              jan    1.56
# 11  Light_snowrain    1.27
# 8              sep    1.17

# %% [markdown]
# ## Building a Linear Model

# %%
# Building 1st linear regression model

X_train_lm_1 = sm.add_constant(X_train_rfe)
lr_1 = sm.OLS(y_train,X_train_lm_1.astype(float)).fit()
print(lr_1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.820
# Model:                            OLS   Adj. R-squared:                  0.815
# Method:                 Least Squares   F-statistic:                     160.7
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):          7.63e-174
# Time:                        00:25:57   Log-Likelihood:                 475.75
# No. Observations:                 510   AIC:                            -921.5
# Df Residuals:                     495   BIC:                            -858.0
# Df Model:                          14
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.3005      0.082      3.663      0.000       0.139       0.462
# year               0.2309      0.009     26.515      0.000       0.214       0.248
# holiday           -0.1366      0.070     -1.959      0.051      -0.274       0.000
# workingday        -0.0432      0.076     -0.570      0.569      -0.192       0.106
# temp               0.4201      0.137      3.078      0.002       0.152       0.688
# atemp              0.1227      0.145      0.844      0.399      -0.163       0.409
# humidity          -0.1458      0.040     -3.620      0.000      -0.225      -0.067
# windspeed         -0.1728      0.028     -6.199      0.000      -0.228      -0.118
# jan               -0.0762      0.018     -4.208      0.000      -0.112      -0.041
# sep                0.0782      0.016      4.799      0.000       0.046       0.110
# sat               -0.0277      0.076     -0.367      0.714      -0.176       0.121
# sun               -0.0256      0.076     -0.339      0.735      -0.174       0.123
# Light_snowrain    -0.2457      0.028     -8.690      0.000      -0.301      -0.190
# Misty             -0.0499      0.011     -4.434      0.000      -0.072      -0.028
# winter             0.0950      0.011      8.344      0.000       0.073       0.117
# ==============================================================================
# Omnibus:                       52.091   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               95.569
# Skew:                          -0.628   Prob(JB):                     1.77e-21
# Kurtosis:                       4.709   Cond. No.                         82.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# As humidity shows high VIF values hence we can drop it
X_train_new = X_train_rfe.drop(['humidity'], axis = 1)

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#           Features     VIF
# 4            atemp  353.99
# 3             temp  345.61
# 2       workingday   15.51
# 5        windspeed    5.16
# 9              sun    3.79
# 8              sat    3.57
# 0             year    2.06
# 12          winter    1.68
# 11           Misty    1.58
# 6              jan    1.54
# 1          holiday    1.36
# 7              sep    1.16
# 10  Light_snowrain    1.09

# %%
# Building 2nd linear regression model

X_train_lm_2 = sm.add_constant(X_train_new)
lr_2 = sm.OLS(y_train,X_train_lm_2.astype(float)).fit()
print(lr_2.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     168.0
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):          3.59e-172
# Time:                        00:25:57   Log-Likelihood:                 469.09
# No. Observations:                 510   AIC:                            -910.2
# Df Residuals:                     496   BIC:                            -850.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2078      0.079      2.634      0.009       0.053       0.363
# year               0.2343      0.009     26.743      0.000       0.217       0.252
# holiday           -0.1274      0.071     -1.806      0.072      -0.266       0.011
# workingday        -0.0314      0.077     -0.410      0.682      -0.182       0.119
# temp               0.4301      0.138      3.113      0.002       0.159       0.701
# atemp              0.0882      0.147      0.600      0.549      -0.201       0.377
# windspeed         -0.1475      0.027     -5.400      0.000      -0.201      -0.094
# jan               -0.0802      0.018     -4.381      0.000      -0.116      -0.044
# sep                0.0741      0.016      4.503      0.000       0.042       0.106
# sat               -0.0139      0.076     -0.183      0.855      -0.164       0.136
# sun               -0.0110      0.076     -0.144      0.886      -0.161       0.139
# Light_snowrain    -0.2856      0.026    -10.839      0.000      -0.337      -0.234
# Misty             -0.0734      0.009     -7.890      0.000      -0.092      -0.055
# winter             0.0869      0.011      7.693      0.000       0.065       0.109
# ==============================================================================
# Omnibus:                       49.627   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.587
# Skew:                          -0.624   Prob(JB):                     2.60e-19
# Kurtosis:                       4.572   Cond. No.                         76.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Check if 'nov' exists in X_train_new before dropping it
if 'nov' in X_train_new.columns:
    # Drop the 'nov' variable as it has a high VIF
    X_train_new = X_train_new.drop(['nov'], axis=1)
else:
    print("'nov' column not found in X_train_new.")

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
# 'nov' column not found in X_train_new.
#           Features     VIF
# 4            atemp  353.99
# 3             temp  345.61
# 2       workingday   15.51
# 5        windspeed    5.16
# 9              sun    3.79
# 8              sat    3.57
# 0             year    2.06
# 12          winter    1.68
# 11           Misty    1.58
# 6              jan    1.54
# 1          holiday    1.36
# 7              sep    1.16
# 10  Light_snowrain    1.09

# %%
# Building 3rd linear regression model

X_train_lm_3 = sm.add_constant(X_train_new)
lr_3 = sm.OLS(y_train,X_train_lm_3.astype(float)).fit()
print(lr_3.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     168.0
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):          3.59e-172
# Time:                        00:25:57   Log-Likelihood:                 469.09
# No. Observations:                 510   AIC:                            -910.2
# Df Residuals:                     496   BIC:                            -850.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2078      0.079      2.634      0.009       0.053       0.363
# year               0.2343      0.009     26.743      0.000       0.217       0.252
# holiday           -0.1274      0.071     -1.806      0.072      -0.266       0.011
# workingday        -0.0314      0.077     -0.410      0.682      -0.182       0.119
# temp               0.4301      0.138      3.113      0.002       0.159       0.701
# atemp              0.0882      0.147      0.600      0.549      -0.201       0.377
# windspeed         -0.1475      0.027     -5.400      0.000      -0.201      -0.094
# jan               -0.0802      0.018     -4.381      0.000      -0.116      -0.044
# sep                0.0741      0.016      4.503      0.000       0.042       0.106
# sat               -0.0139      0.076     -0.183      0.855      -0.164       0.136
# sun               -0.0110      0.076     -0.144      0.886      -0.161       0.139
# Light_snowrain    -0.2856      0.026    -10.839      0.000      -0.337      -0.234
# Misty             -0.0734      0.009     -7.890      0.000      -0.092      -0.055
# winter             0.0869      0.011      7.693      0.000       0.065       0.109
# ==============================================================================
# Omnibus:                       49.627   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.587
# Skew:                          -0.624   Prob(JB):                     2.60e-19
# Kurtosis:                       4.572   Cond. No.                         76.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Check if 'dec' exists in X_train_new before dropping it
if 'dec' in X_train_new.columns:
    # Drop the 'nov' variable as it has a high VIF
    X_train_new = X_train_new.drop(['dec'], axis=1)
else:
    print("'dec' column not found in X_train_new.")

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
# 'dec' column not found in X_train_new.
#           Features     VIF
# 4            atemp  353.99
# 3             temp  345.61
# 2       workingday   15.51
# 5        windspeed    5.16
# 9              sun    3.79
# 8              sat    3.57
# 0             year    2.06
# 12          winter    1.68
# 11           Misty    1.58
# 6              jan    1.54
# 1          holiday    1.36
# 7              sep    1.16
# 10  Light_snowrain    1.09

# %%
# Building 4th linear regression model

X_train_lm_4 = sm.add_constant(X_train_new)
lr_4 = sm.OLS(y_train,X_train_lm_4.astype(float)).fit()
print(lr_4.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.815
# Model:                            OLS   Adj. R-squared:                  0.810
# Method:                 Least Squares   F-statistic:                     168.0
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):          3.59e-172
# Time:                        00:25:57   Log-Likelihood:                 469.09
# No. Observations:                 510   AIC:                            -910.2
# Df Residuals:                     496   BIC:                            -850.9
# Df Model:                          13
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2078      0.079      2.634      0.009       0.053       0.363
# year               0.2343      0.009     26.743      0.000       0.217       0.252
# holiday           -0.1274      0.071     -1.806      0.072      -0.266       0.011
# workingday        -0.0314      0.077     -0.410      0.682      -0.182       0.119
# temp               0.4301      0.138      3.113      0.002       0.159       0.701
# atemp              0.0882      0.147      0.600      0.549      -0.201       0.377
# windspeed         -0.1475      0.027     -5.400      0.000      -0.201      -0.094
# jan               -0.0802      0.018     -4.381      0.000      -0.116      -0.044
# sep                0.0741      0.016      4.503      0.000       0.042       0.106
# sat               -0.0139      0.076     -0.183      0.855      -0.164       0.136
# sun               -0.0110      0.076     -0.144      0.886      -0.161       0.139
# Light_snowrain    -0.2856      0.026    -10.839      0.000      -0.337      -0.234
# Misty             -0.0734      0.009     -7.890      0.000      -0.092      -0.055
# winter             0.0869      0.011      7.693      0.000       0.065       0.109
# ==============================================================================
# Omnibus:                       49.627   Durbin-Watson:                   2.026
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               85.587
# Skew:                          -0.624   Prob(JB):                     2.60e-19
# Kurtosis:                       4.572   Cond. No.                         76.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Check if 'jan' exists in X_train_new before dropping it
if 'jan' in X_train_new.columns:
    # Drop the 'jan' variable as it has a high VIF
    X_train_new = X_train_new.drop(['jan'], axis=1)
else:
    print("'jan' column not found in X_train_new.")

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
#           Features     VIF
# 4            atemp  353.26
# 3             temp  345.02
# 2       workingday   11.88
# 5        windspeed    5.07
# 8              sun    3.12
# 7              sat    2.91
# 0             year    2.05
# 10           Misty    1.58
# 11          winter    1.50
# 1          holiday    1.25
# 6              sep    1.16
# 9   Light_snowrain    1.09

# %%
# Building 5th linear regression model

X_train_lm_5 = sm.add_constant(X_train_new)
lr_5 = sm.OLS(y_train,X_train_lm_5.astype(float)).fit()
print(lr_5.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     174.0
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):          3.11e-169
# Time:                        00:25:57   Log-Likelihood:                 459.41
# No. Observations:                 510   AIC:                            -892.8
# Df Residuals:                     497   BIC:                            -837.8
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.1569      0.079      1.975      0.049       0.001       0.313
# year               0.2327      0.009     26.105      0.000       0.215       0.250
# holiday           -0.1255      0.072     -1.748      0.081      -0.267       0.016
# workingday        -0.0261      0.078     -0.335      0.738      -0.179       0.127
# temp               0.4538      0.141      3.229      0.001       0.178       0.730
# atemp              0.1218      0.149      0.815      0.415      -0.172       0.415
# windspeed         -0.1301      0.028     -4.728      0.000      -0.184      -0.076
# sep                0.0742      0.017      4.432      0.000       0.041       0.107
# sat               -0.0091      0.078     -0.117      0.907      -0.162       0.144
# sun               -0.0052      0.078     -0.067      0.947      -0.158       0.147
# Light_snowrain    -0.2822      0.027    -10.524      0.000      -0.335      -0.230
# Misty             -0.0743      0.009     -7.846      0.000      -0.093      -0.056
# winter             0.1031      0.011      9.492      0.000       0.082       0.124
# ==============================================================================
# Omnibus:                       47.183   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.420
# Skew:                          -0.597   Prob(JB):                     2.09e-18
# Kurtosis:                       4.550   Cond. No.                         76.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Check if 'july' exists in X_train_new before dropping it
if 'july' in X_train_new.columns:
    # Drop the 'july' variable as it has a high VIF
    X_train_new = X_train_new.drop(['july'], axis=1)
else:
    print("'july' column not found in X_train_new.")

# Run the function to calculate VIF for the new model
calculateVIF(X_train_new)
# Out:
# 'july' column not found in X_train_new.
#           Features     VIF
# 4            atemp  353.26
# 3             temp  345.02
# 2       workingday   11.88
# 5        windspeed    5.07
# 8              sun    3.12
# 7              sat    2.91
# 0             year    2.05
# 10           Misty    1.58
# 11          winter    1.50
# 1          holiday    1.25
# 6              sep    1.16
# 9   Light_snowrain    1.09

# %%
# Building 6th linear regression model

X_train_lm_6 = sm.add_constant(X_train_new)
lr_6 = sm.OLS(y_train,X_train_lm_6.astype(float)).fit()
print(lr_6.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.803
# Method:                 Least Squares   F-statistic:                     174.0
# Date:                Tue, 30 Apr 2024   Prob (F-statistic):          3.11e-169
# Time:                        00:25:57   Log-Likelihood:                 459.41
# No. Observations:                 510   AIC:                            -892.8
# Df Residuals:                     497   BIC:                            -837.8
# Df Model:                          12
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.1569      0.079      1.975      0.049       0.001       0.313
# year               0.2327      0.009     26.105      0.000       0.215       0.250
# holiday           -0.1255      0.072     -1.748      0.081      -0.267       0.016
# workingday        -0.0261      0.078     -0.335      0.738      -0.179       0.127
# temp               0.4538      0.141      3.229      0.001       0.178       0.730
# atemp              0.1218      0.149      0.815      0.415      -0.172       0.415
# windspeed         -0.1301      0.028     -4.728      0.000      -0.184      -0.076
# sep                0.0742      0.017      4.432      0.000       0.041       0.107
# sat               -0.0091      0.078     -0.117      0.907      -0.162       0.144
# sun               -0.0052      0.078     -0.067      0.947      -0.158       0.147
# Light_snowrain    -0.2822      0.027    -10.524      0.000      -0.335      -0.230
# Misty             -0.0743      0.009     -7.846      0.000      -0.093      -0.056
# winter             0.1031      0.011      9.492      0.000       0.082       0.124
# ==============================================================================
# Omnibus:                       47.183   Durbin-Watson:                   2.007
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.420
# Skew:                          -0.597   Prob(JB):                     2.09e-18
# Kurtosis:                       4.550   Cond. No.                         76.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Checking the parameters and their coefficient values
lr_6.params
# Out:
# const             0.156929
# year              0.232657
# holiday          -0.125533
# workingday       -0.026128
# temp              0.453756
# atemp             0.121779
# windspeed        -0.130084
# sep               0.074215
# sat              -0.009120
# sun              -0.005178
# Light_snowrain   -0.282210
# Misty            -0.074340
# winter            0.103120
# dtype: float64

# %% [markdown]
# ## Residual Analysis of the train data and validation

# %%
X_train_lm_6
# Out:
#      const  year  holiday  workingday      temp     atemp  windspeed    sep  \
# 576    1.0     1        0           1  0.815169  0.766351   0.264686  False
# 426    1.0     1        0           0  0.442393  0.438975   0.255342  False
# 728    1.0     1        0           1  0.245101  0.200348   0.663106  False
# 482    1.0     1        0           0  0.395666  0.391735   0.188475  False
# 111    1.0     0        0           0  0.345824  0.318819   0.380981  False
# ..     ...   ...      ...         ...       ...       ...        ...    ...
# 578    1.0     1        0           1  0.863973  0.824359   0.187140  False
# 53     1.0     0        0           1  0.202618  0.218747   0.111379  False
# 350    1.0     0        0           1  0.248216  0.223544   0.431816  False
# 79     1.0     0        0           1  0.462664  0.434043   0.529881  False
# 520    1.0     1        0           1  0.600225  0.586515   0.359599  False
#
#        sat    sun  Light_snowrain  Misty  winter
# 576  False  False           False  False   False
# 426  False   True           False   True   False
# 728  False  False           False  False   False
# 482  False   True           False   True   False
# 111  False   True           False   True   False
# ..     ...    ...             ...    ...     ...
# 578  False  False           False  False   False
# 53   False  False           False  False   False
# 350  False  False           False   True    True
# 79   False  False           False   True   False
# 520  False  False           False   True   False
#
# [510 rows x 13 columns]

# %%
y_train_pred = lr_6.predict(X_train_lm_6)

# %% [markdown]
# ### Normality of error terms

# %%
# Plot the histogram of the error terms

fig = plt.figure()
sns.distplot((y_train - y_train_pred), bins = 20)
fig.suptitle('Error Terms', fontsize = 20) 
plt.xlabel('Errors', fontsize = 18)
# Out:
# Text(0.5, 0, 'Errors')

# %% [markdown]
# ### Multi Colinearity

# %%
calculateVIF(X_train_new)
# Out:
#           Features     VIF
# 4            atemp  353.26
# 3             temp  345.02
# 2       workingday   11.88
# 5        windspeed    5.07
# 8              sun    3.12
# 7              sat    2.91
# 0             year    2.05
# 10           Misty    1.58
# 11          winter    1.50
# 1          holiday    1.25
# 6              sep    1.16
# 9   Light_snowrain    1.09

# %%
plt.figure(figsize=(15,8))
sns.heatmap(X_train_new.corr(),annot = True, cmap="RdYlGn")
plt.show()

# %% [markdown]
# ### Linearity

# %%
# Linear relationship validation using CCPR plot
# Component and component plus residual plot

sm.graphics.plot_ccpr(lr_6, 'temp')
plt.show()

sm.graphics.plot_ccpr(lr_6, 'sep')
plt.show()

sm.graphics.plot_ccpr(lr_6, 'windspeed')
plt.show()

# %% [markdown]
# ### Homoscedasticity

# %%
y_train_pred = lr_6.predict(X_train_lm_6)
residual = y_train - y_train_pred

# Use the 'scatterplot' function correctly
sns.scatterplot(x=y_train, y=residual)

# Plot a horizontal line at y=0 for reference
plt.axhline(y=0, color='red', linestyle='-')

plt.xlabel('Actual Value')
plt.ylabel('Residual')
plt.title('Residual Plot')
plt.show()

# %% [markdown]
# ## Making Predictions Using the Final Model

# %%
# Applying scaling on the test dataset

num_vars = ['temp', 'atemp', 'humidity', 'windspeed','cnt']
df_test[num_vars] = scaler.transform(df_test[num_vars])
df_test.head()
# Out:
#      year  holiday  workingday      temp     atemp  humidity  windspeed  \
# 184     0        1           0  0.831783  0.769660  0.657364   0.084219
# 535     1        0           1  0.901354  0.842587  0.610133   0.153728
# 299     0        0           0  0.511964  0.496145  0.837699   0.334206
# 221     0        0           1  0.881625  0.795343  0.437098   0.339570
# 152     0        0           0  0.817246  0.741471  0.314298   0.537414
#
#           cnt    aug    dec  ...    sat    sun    thu    tue    wed  \
# 184  0.692706  False  False  ...  False  False  False  False   True
# 535  0.712034  False  False  ...  False  False   True  False  False
# 299  0.303382  False  False  ...   True  False  False  False  False
# 221  0.547400   True  False  ...  False  False  False  False  False
# 152  0.569029  False  False  ...   True  False  False  False  False
#
#      Light_snowrain  Misty  spring  summer  winter
# 184           False   True   False   False   False
# 535           False  False   False    True   False
# 299           False   True   False   False    True
# 221           False  False   False   False   False
# 152           False  False   False    True   False
#
# [5 rows x 30 columns]

# %%
df_test.describe()
# Out:
#              year     holiday  workingday        temp       atemp    humidity  \
# count  220.000000  220.000000  220.000000  220.000000  220.000000  220.000000
# mean     0.481818    0.036364    0.640909    0.558718    0.532847    0.638221
# std      0.500809    0.187620    0.480828    0.233187    0.217401    0.148694
# min      0.000000    0.000000    0.000000    0.046591    0.025950    0.261915
# 25%      0.000000    0.000000    0.000000    0.355429    0.344870    0.529197
# 50%      0.000000    0.000000    1.000000    0.558172    0.544652    0.625590
# 75%      1.000000    0.000000    1.000000    0.755981    0.713308    0.743798
# max      1.000000    1.000000    1.000000    0.984424    0.980934    1.002146
#
#         windspeed         cnt
# count  220.000000  220.000000
# mean     0.313293    0.522154
# std      0.159584    0.219163
# min     -0.042808    0.048205
# 25%      0.198843    0.378595
# 50%      0.300126    0.524678
# 75%      0.402718    0.677750
# max      0.807474    0.963300

# %%
y_test = df_test.pop('cnt')
X_test = df_test

# %%
col1 = X_train_new.columns

X_test = X_test[col1]

# Adding constant variable to test dataframe
X_test_lm_6 = sm.add_constant(X_test)

# %%
y_pred = lr_6.predict(X_test_lm_6)

# %%
r2 = r2_score(y_test, y_pred)
round(r2,4)
# Out:
# 0.7763

# %% [markdown]
# ## Model Evaluation

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure()
plt.scatter(y_test, y_pred)
fig.suptitle('y_test vs y_pred', fontsize = 20) 
plt.xlabel('y_test', fontsize = 18)
plt.ylabel('y_pred', fontsize = 16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
round(lr_6.params,4)
# Out:
# const             0.1569
# year              0.2327
# holiday          -0.1255
# workingday       -0.0261
# temp              0.4538
# atemp             0.1218
# windspeed        -0.1301
# sep               0.0742
# sat              -0.0091
# sun              -0.0052
# Light_snowrain   -0.2822
# Misty            -0.0743
# winter            0.1031
# dtype: float64

# %%
# Calculating Adjusted-R^2 value for the test dataset

adjusted_r2 = round(1-(1-r2)*(X_test.shape[0]-1)/(X_test.shape[0]-X_test.shape[1]-1),4)
print(adjusted_r2)
# Out:
# 0.7633

# %% [markdown]
# ## Comparision between Training and Testing dataset:

# %% [raw]
# - Train dataset R^2          : 0.833
# - Test dataset R^2           : 0.8038
# - Train dataset Adjusted R^2 : 0.803
# - Test dataset Adjusted R^2  : 0.7633

# %% [markdown]
# Demand of bikes depend on year, holiday, temp, windspeed, sep, Light_snowrain, Misty, spring, summer and winter.
